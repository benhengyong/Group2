# %%
#importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np

# %%
data1 =pd.read_excel('Data/Table 1. Retail turnover, by industry group 850101.xlsx',sheet_name="Data1")
data1 = data1.drop(range(0,9))
data1 = data1.rename(columns = {'Unnamed: 0':'Month'})
data1.head()
# 6 Different Indsutries in this Dataframe, SEASONALLY ADJUSTED IS MOST ACCURATE
# Out:
#                   Month Turnover ;  Total (State) ;  Food retailing ;  \
# 9   1982-04-01 00:00:00                                        1162.6
# 10  1982-05-01 00:00:00                                        1150.9
# 11  1982-06-01 00:00:00                                          1160
# 12  1982-07-01 00:00:00                                        1206.4
# 13  1982-08-01 00:00:00                                        1152.5
#
#    Turnover ;  Total (State) ;  Household goods retailing ;  \
# 9                                               592.3
# 10                                              629.6
# 11                                              607.4
# 12                                              632.4
# 13                                              622.6
#
#    Turnover ;  Total (State) ;  Clothing, footwear and personal accessory retailing ;  \
# 9                                               359.9
# 10                                              386.6
# ...

# %%
data_by_state =pd.read_excel('Data/Table 3. Retail turnover, by state 850103.xlsx',sheet_name="Data1")
data_by_state = data_by_state.drop(range(0,9))
data_by_state = data_by_state.rename(columns = {'Unnamed: 0':'Month'})
data_by_state.head()
# Out:
#                   Month Turnover ;  New South Wales ;  Total (Industry) ;  \
# 9   1982-04-01 00:00:00                                            1250.2
# 10  1982-05-01 00:00:00                                              1300
# 11  1982-06-01 00:00:00                                            1234.2
# 12  1982-07-01 00:00:00                                              1265
# 13  1982-08-01 00:00:00                                            1217.6
#
#    Turnover ;  Victoria ;  Total (Industry) ;  \
# 9                                       916.2
# 10                                      931.2
# 11                                        887
# 12                                      921.3
# 13                                      883.2
#
#    Turnover ;  Queensland ;  Total (Industry) ;  \
# 9                                         486.3
# 10                                        492.8
# 11                                        494.1
# ...

# %%
data_by_state_and_industry =pd.read_excel('Data/Table 12. Retail turnover, state by industry subgroup, seasonally adjusted.xlsx',sheet_name="Data1")
data_by_state_and_industry = data_by_state_and_industry.drop(range(0,9))
data_by_state_and_industry = data_by_state_and_industry.rename(columns = {'Unnamed: 0':'Month'})
data_by_state_and_industry.head()
# Out:
#                   Month  \
# 9   1982-04-01 00:00:00
# 10  1982-05-01 00:00:00
# 11  1982-06-01 00:00:00
# 12  1982-07-01 00:00:00
# 13  1982-08-01 00:00:00
#
#    Turnover ;  New South Wales ;  Supermarket and grocery stores ;  \
# 9                                               307.1
# 10                                              307.4
# 11                                              308.9
# 12                                              309.3
# 13                                              310.7
#
#    Turnover ;  New South Wales ;  Liquor retailing ;  \
# 9                                               43.6
# 10                                              44.7
# 11                                              44.4
# 12                                              44.6
# 13                                              44.9
#
#    Turnover ;  New South Wales ;  Other specialised food retailing ;  \
# 9                                                  65
# ...

# %%
#Question four made by ben
question_3_data = data_by_state_and_industry.loc[:,["Month",
                                                   "Turnover ;  New South Wales ;  Food retailing ;",
                                                   "Turnover ;  New South Wales ;  Household goods retailing ;",
                                                   "Turnover ;  New South Wales ;  Clothing, footwear and personal accessory retailing ;",
                                                   "Turnover ;  New South Wales ;  Department stores ;",
                                                   "Turnover ;  New South Wales ;  Other retailing ;",
                                                   "Turnover ;  New South Wales ;  Cafes, restaurants and takeaway food services ;",
                                                   "Turnover ;  Victoria ;  Food retailing ;",
                                                   "Turnover ;  Victoria ;  Household goods retailing ;",
                                                   "Turnover ;  Victoria ;  Clothing, footwear and personal accessory retailing ;",
                                                   "Turnover ;  Victoria ;  Department stores ;",
                                                   "Turnover ;  Victoria ;  Other retailing ;",
                                                   "Turnover ;  Victoria ;  Cafes, restaurants and takeaway food services ;",
                                                   "Turnover ;  Queensland ;  Food retailing ;",
                                                   "Turnover ;  Queensland ;  Household goods retailing ;",
                                                   "Turnover ;  Queensland ;  Clothing, footwear and personal accessory retailing ;",
                                                   "Turnover ;  Queensland ;  Department stores ;", 
                                                   "Turnover ;  Queensland ;  Other retailing ;", 
                                                   "Turnover ;  Queensland ;  Cafes, restaurants and takeaway food services ;",
                                                   "Turnover ;  South Australia ;  Food retailing ;",  
                                                   "Turnover ;  South Australia ;  Household goods retailing ;", 
                                                   "Turnover ;  South Australia ;  Clothing, footwear and personal accessory retailing ;",
                                                   "Turnover ;  South Australia ;  Department stores ;",
                                                   "Turnover ;  South Australia ;  Other retailing ;",
                                                   "Turnover ;  South Australia ;  Cafes, restaurants and takeaway food services ;", 
                                                   "Turnover ;  Western Australia ;  Food retailing ;", 
                                                   "Turnover ;  Western Australia ;  Household goods retailing ;",
                                                   "Turnover ;  Western Australia ;  Clothing, footwear and personal accessory retailing ;",  
                                                   "Turnover ;  Western Australia ;  Department stores ;",
                                                   "Turnover ;  Western Australia ;  Other retailing ;",  
                                                   "Turnover ;  Western Australia ;  Cafes, restaurants and takeaway food services ;", 
                                                   "Turnover ;  Tasmania ;  Food retailing ;", 
                                                   "Turnover ;  Tasmania ;  Household goods retailing ;",  
                                                   "Turnover ;  Tasmania ;  Clothing, footwear and personal accessory retailing ;", 
                                                   "Turnover ;  Tasmania ;  Department stores ;",  
                                                   "Turnover ;  Tasmania ;  Other retailing ;",  
                                                   "Turnover ;  Tasmania ;  Cafes, restaurants and takeaway food services ;",
                                                   "Turnover ;  Northern Territory ;  Food retailing ;",  
                                                   "Turnover ;  Northern Territory ;  Household goods retailing ;",
                                                   "Turnover ;  Northern Territory ;  Clothing, footwear and personal accessory retailing ;",
                                                   "Turnover ;  Northern Territory ;  Department stores ;", 
                                                   "Turnover ;  Northern Territory ;  Other retailing ;",  
                                                   "Turnover ;  Northern Territory ;  Cafes, restaurants and takeaway food services ;", 
                                                   "Turnover ;  Australian Capital Territory ;  Food retailing ;",
                                                   "Turnover ;  Australian Capital Territory ;  Household goods retailing ;", 
                                                   "Turnover ;  Australian Capital Territory ;  Clothing, footwear and personal accessory retailing ;", 
                                                   "Turnover ;  Australian Capital Territory ;  Department stores ;",
                                                   "Turnover ;  Australian Capital Territory ;  Other retailing ;",
                                                   "Turnover ;  Australian Capital Territory ;  Cafes, restaurants and takeaway food services ;"
                                                   ]]

#Filters data from January 2013 to last date September 2023
question_3_data = question_3_data.drop(range(9,378))
question_3_data

#For question 4 filters data down to past two years to find greatest growth
question_3_data = question_3_data.drop(range(378,474))
question_3_data

#Calculates the average monthly percentage change of turnover
average_change = []
for column in question_3_data:
    if column == 'Month':
        pass
    else:
        question_3_data[f"Yearly change of {column}"]=question_3_data[column].pct_change()*100
        average_change.append(question_3_data[f"Yearly change of {column}"].mean()) 
question_3_data

#Plotting the graph
x_axis=["Food retailing","Household goods retailing","Clothing, footwear and personal accessory retailing","Department stores ",
        "Other retailing","Cafes, restaurants and takeaway food services"]

plt.xticks(rotation = 90)
plt.xlabel("Name of industries")
plt.ylabel("% Average Monthly change of turnover")
plt.title("% Average change in industry turnovers in New South Wales")
plt.bar(x_axis, average_change[0:6]) #Can change states by changing the number in the average change
plt.show()

# From question 3 data, create new dataframe with only data from chosen state
chosen_state = 'New South Wales'

chosen_state_df = question_3_data.filter(regex= f'Month|{chosen_state}')
chosen_state_df = chosen_state_df.filter(regex= f'Month|Yearly change')

# Create a line chart showing the industry turnover by time for the chosen state
chosen_state_df.plot(x = 'Month')

plt.title(f"% change in turnovers of {chosen_state} ")
plt.xlabel('Time')
plt.ylabel('% change in turnovers')
plt.legend()
plt.legend(bbox_to_anchor=(1.04, 1), loc="upper left")

plt.show()

# %%
###### Vy's question 4 #####
# Extract data for each industry
question_4_df = data_by_state_and_industry.loc[:,["Month",
                                                  "Turnover ;  New South Wales ;  Food retailing ;",
                                                   "Turnover ;  Victoria ;  Food retailing ;",
                                                   "Turnover ;  Queensland ;  Food retailing ;",
                                                   "Turnover ;  South Australia ;  Food retailing ;",
                                                   "Turnover ;  Western Australia ;  Food retailing ;",
                                                   "Turnover ;  Tasmania ;  Food retailing ;",
                                                   "Turnover ;  Northern Territory ;  Food retailing ;",
                                                   "Turnover ;  Australian Capital Territory ;  Food retailing ;",
                                                   "Turnover ;  New South Wales ;  Household goods retailing ;",
                                                   "Turnover ;  Victoria ;  Household goods retailing ;",
                                                   "Turnover ;  Queensland ;  Household goods retailing ;",
                                                   "Turnover ;  South Australia ;  Household goods retailing ;",
                                                   "Turnover ;  Western Australia ;  Household goods retailing ;",
                                                   "Turnover ;  Tasmania ;  Household goods retailing ;",
                                                   "Turnover ;  Northern Territory ;  Household goods retailing ;",
                                                   "Turnover ;  Australian Capital Territory ;  Household goods retailing ;",
                                                   "Turnover ;  New South Wales ;  Clothing, footwear and personal accessory retailing ;",
                                                   "Turnover ;  Victoria ;  Clothing, footwear and personal accessory retailing ;",
                                                   "Turnover ;  Queensland ;  Clothing, footwear and personal accessory retailing ;",
                                                   "Turnover ;  South Australia ;  Clothing, footwear and personal accessory retailing ;",
                                                   "Turnover ;  Western Australia ;  Clothing, footwear and personal accessory retailing ;",
                                                   "Turnover ;  Tasmania ;  Clothing, footwear and personal accessory retailing ;",
                                                   "Turnover ;  Northern Territory ;  Clothing, footwear and personal accessory retailing ;",
                                                   "Turnover ;  Australian Capital Territory ;  Clothing, footwear and personal accessory retailing ;",
                                                   "Turnover ;  New South Wales ;  Department stores ;",
                                                   "Turnover ;  Victoria ;  Department stores ;",
                                                   "Turnover ;  Queensland ;  Department stores ;",
                                                   "Turnover ;  South Australia ;  Department stores ;",
                                                   "Turnover ;  Western Australia ;  Department stores ;",
                                                   "Turnover ;  Tasmania ;  Department stores ;",
                                                   "Turnover ;  Northern Territory ;  Department stores ;",
                                                   "Turnover ;  Australian Capital Territory ;  Department stores ;",
                                                   "Turnover ;  New South Wales ;  Other retailing ;",
                                                   "Turnover ;  Victoria ;  Other retailing ;",
                                                   "Turnover ;  Queensland ;  Other retailing ;",
                                                   "Turnover ;  South Australia ;  Other retailing ;",
                                                   "Turnover ;  Western Australia ;  Other retailing ;",
                                                   "Turnover ;  Tasmania ;  Other retailing ;",
                                                   "Turnover ;  Northern Territory ;  Other retailing ;",
                                                   "Turnover ;  Australian Capital Territory ;  Other retailing ;",
                                                   "Turnover ;  New South Wales ;  Cafes, restaurants and takeaway food services ;",
                                                   "Turnover ;  Victoria ;  Cafes, restaurants and takeaway food services ;",
                                                   "Turnover ;  Queensland ;  Cafes, restaurants and takeaway food services ;",
                                                   "Turnover ;  South Australia ;  Cafes, restaurants and takeaway food services ;",
                                                   "Turnover ;  Western Australia ;  Cafes, restaurants and takeaway food services ;",
                                                   "Turnover ;  Tasmania ;  Cafes, restaurants and takeaway food services ;",
                                                   "Turnover ;  Northern Territory ;  Cafes, restaurants and takeaway food services ;",
                                                   "Turnover ;  Australian Capital Territory ;  Cafes, restaurants and takeaway food services ;"
                                                   ]]

# From data_by_state_and_industry, create new dataframe with only data from chosen state
chosen_state = 'South Australia'

chosen_state_df = question_4_df.filter(regex= f'Month|{chosen_state}')

# Create a line chart showing the industry turnover by time for the chosen state
chosen_state_df.plot(x = 'Month')

plt.title(f"The turn over of industries in {chosen_state} ")
plt.xlabel('Time')
plt.ylabel('Turn over ($ Millions)')
plt.legend()
plt.legend(bbox_to_anchor=(1.04, 1), loc="upper left")

plt.show()
